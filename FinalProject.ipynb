# %%
import numpy as np
import pandas as pd

# %%
airbnb_data = pd.read_csv('dataset/airbnb.csv')
airbnb_data
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
airbnb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35238 entries, 1 to 48894
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              35238 non-null  int64
#  1   name                            35238 non-null  object
#  2   host_id                         35238 non-null  int64
#  3   host_name                       35238 non-null  object
#  4   neighbourhood_group             35238 non-null  object
#  5   neighbourhood                   35238 non-null  object
#  6   latitude                        35238 non-null  float64
#  7   longitude                       35238 non-null  float64
#  8   room_type                       35238 non-null  object
#  9   price                           35238 non-null  int64
#  10  minimum_nights                  35238 non-null  int64
#  11  number_of_reviews               35238 non-null  int64
# ...

# %%
airbnb_data.describe(include = "all")
# Out:
#                   id            name       host_id host_name  \
# count   4.889500e+04           48879  4.889500e+04     48874
# unique           NaN           47905           NaN     11452
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.901714e+07             NaN  6.762001e+07       NaN
# std     1.098311e+07             NaN  7.861097e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.471945e+06             NaN  7.822033e+06       NaN
# 50%     1.967728e+07             NaN  3.079382e+07       NaN
# 75%     2.915218e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48895         48895  48895.000000  48895.000000
# unique                   5           221           NaN           NaN
# ...

# %%
airbnb_data.dropna(subset=['name', 'host_name'], inplace=True)

# %%
values = airbnb_data["last_review"].value_counts().index.tolist()
counts = airbnb_data["last_review"].value_counts().tolist()
val_counts = dict(zip(values, counts))
val_counts
# Out:
# {'2019-06-23': 1413,
#  '2019-07-01': 1359,
#  '2019-06-30': 1341,
#  '2019-06-24': 875,
#  '2019-07-07': 717,
#  '2019-07-02': 657,
#  '2019-06-22': 655,
#  '2019-06-16': 601,
#  '2019-07-05': 580,
#  '2019-07-06': 565,
#  '2019-06-29': 529,
#  '2019-06-21': 529,
#  '2019-07-03': 426,
#  '2019-06-19': 424,
#  '2019-06-25': 423,
#  '2019-06-20': 421,
#  '2019-06-28': 399,
#  '2019-01-01': 396,
#  '2019-06-26': 390,
#  '2019-06-09': 383,
#  '2019-06-17': 376,
#  '2019-06-15': 370,
#  '2019-05-27': 347,
#  '2019-06-18': 340,
#  '2019-06-27': 334,
#  '2019-07-04': 330,
#  '2019-01-02': 299,
#  '2019-06-10': 298,
#  '2019-06-02': 291,
#  '2019-05-31': 288,
#  '2019-05-26': 263,
#  '2019-06-14': 263,
#  '2019-06-01': 262,
#  '2019-05-19': 260,
#  '2019-06-08': 249,
#  '2019-06-03': 236,
#  '2019-06-13': 222,
#  '2019-06-11': 208,
#  '2019-06-12': 201,
#  '2019-05-20': 173,
#  '2019-05-28': 169,
#  '2018-01-01': 167,
#  '2019-06-04': 158,
#  '2019-06-07': 155,
#  '2019-05-25': 151,
# ...

# %%
airbnb_data["last_review"] = airbnb_data["last_review"].fillna('2019-06-23')

# %%
airbnb_data["reviews_per_month"] = airbnb_data["reviews_per_month"].fillna('1.373229')

# %%
airbnb_data
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
airbnb_data["last_review"] = pd.to_datetime(airbnb_data["last_review"],format= "%Y-%m-%d")

# %%
airbnb_data["reviews_per_month"] = pd.to_numeric(airbnb_data["last_review"], downcast="float")

# %%
#Make Price Category
airbnb_data["price_category"] = np.where(airbnb_data["price"] > 106, "Expensive", (np.where(airbnb_data["price"] > 69, "Medium", "Cheap")))
airbnb_data
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
values = airbnb_data["price_category"].value_counts().index.tolist()
counts = airbnb_data["price_category"].value_counts().tolist()
val_counts = dict(zip(values, counts))
val_counts
# Out:
# {'Expensive': 24405, 'Cheap': 12360, 'Medium': 12093}

# %%
#Filter the data with last review > 2019
airbnb_data = airbnb_data.loc[airbnb_data["last_review"] >= "2019-01-01"]

# %%
airbnb_data
# Out:
#              id                                               name   host_id  \
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 5          5099          Large Cozy 1 BR Apartment In Midtown East      7322
# 7          5178                   Large Furnished Room Near B'way       8967
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
airbnb_data.describe()
# Out:
#                  id       host_id      latitude     longitude        price  \
# count  3.523800e+04  3.523800e+04  35238.000000  35238.000000  35238.00000
# mean   2.123324e+07  7.918224e+07     40.728544    -73.950290    156.37434
# std    1.115455e+07  8.511670e+07      0.055311      0.049153    229.67447
# min    2.595000e+03  2.571000e+03     40.499790    -74.244420      0.00000
# 25%    1.205578e+07  9.308019e+06     40.689593    -73.983400     69.00000
# 50%    2.254826e+07  3.994302e+07     40.723250    -73.954760    110.00000
# 75%    3.111930e+07  1.373589e+08     40.762810    -73.932533    180.00000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.00000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    35238.000000       35238.000000       3.523800e+04
# mean         6.760344          28.748028       1.559786e+18
# std         17.371446          50.169539       3.502386e+15
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter

# %%
airbnb_data["availability_in_4_month"] = np.where(airbnb_data["availability_365"] > 240, "more than 8 month", 
                                                      (np.where(airbnb_data["availability_365"] > 120, "4 - 8 month", " less than 4 month")))
airbnb_data
# Out:
# <ipython-input-49-8a1c8d4c84f8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   airbnb_data["availability_in_4_month"] = np.where(airbnb_data["availability_365"] > 240, "more than 8 month",
#              id                                               name   host_id  \
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 5          5099          Large Cozy 1 BR Apartment In Midtown East      7322
# 7          5178                   Large Furnished Room Near B'way       8967
# ...

# %%
airbnb_data.plot(kind='bar', x='availability_365', y='price')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-5c87fb46053f> in <module>
# ----> 1 airbnb_data.plot(kind='bar', x='availability_365', y='price')
#
# c:\users\eriko\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# c:\users\eriko\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ...
